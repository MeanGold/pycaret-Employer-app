# %%
pip install pycaret
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pycaret.datasets import get_data
employee = get_data('employee')

employee = employee[['satisfaction_level', 'last_evaluation', 'average_montly_hours', 'time_spend_company', 'department', 'salary', 'left']]
employee
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  promotion_last_5years department  \
# 0                   3              0                      0      sales
# 1                   6              0                      0      sales
# 2                   4              0                      0      sales
# 3                   5              0                      0      sales
# 4                   3              0                      0      sales
#
#    salary  left
# 0     low     1
# 1  medium     1
# 2  medium     1
# ...

# %%
employee.satisfaction_level.unique()
# Out:
# array([0.38, 0.8 , 0.11, 0.72, 0.37, 0.41, 0.1 , 0.92, 0.89, 0.42, 0.45,
#        0.84, 0.36, 0.78, 0.76, 0.09, 0.46, 0.4 , 0.82, 0.87, 0.57, 0.43,
#        0.13, 0.44, 0.39, 0.85, 0.81, 0.9 , 0.74, 0.79, 0.17, 0.24, 0.91,
#        0.71, 0.86, 0.14, 0.75, 0.7 , 0.31, 0.73, 0.83, 0.32, 0.54, 0.27,
#        0.77, 0.88, 0.48, 0.19, 0.6 , 0.12, 0.61, 0.33, 0.56, 0.47, 0.28,
#        0.55, 0.53, 0.59, 0.66, 0.25, 0.34, 0.58, 0.51, 0.35, 0.64, 0.5 ,
#        0.23, 0.15, 0.49, 0.3 , 0.63, 0.21, 0.62, 0.29, 0.2 , 0.16, 0.65,
#        0.68, 0.67, 0.22, 0.26, 0.99, 0.98, 1.  , 0.52, 0.93, 0.97, 0.69,
#        0.94, 0.96, 0.18, 0.95])

# %%
employee.left.sum()
# Out:
# 3571

# %%
# Importing module and initializing setup
from pycaret.classification import *
clf1 = setup(data = employee, target = 'left')

# create a model
randomForest = create_model('rf')
# Out:
# <style type="text/css">
# #T_0d0b4_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0d0b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d0b4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0d0b4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d0b4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d0b4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0d0b4_row0_col1" class="data row0 col1" >5004</td>
#     </tr>
#     <tr>
#       <th id="T_0d0b4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0d0b4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0d0b4_row1_col1" class="data row1 col1" >left</td>
#     </tr>
#     <tr>
#       <th id="T_0d0b4_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
rf_final = finalize_model(randomForest)

# %%
save_model(rf_final, 'modelEmployer001')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['satisfaction_level',
#                                               'last_evaluation',
#                                               'average_montly_hours',
#                                               'time_spend_company'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean',
# ...
